# %%
using PyPlot

# %%
x = range(0, stop = 2*pi, length = 1000);
y = sin.(3 * x + 4 * cos.(2 * x));

# %%
plot(x, y, color = "red", linewidth = 2.0, linestyle = "--")
title("Sinusoid")

savefig("figures/pyplot.png")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
